# %% [markdown]
# ## **PRODIGY_DS_01**

# %% [markdown]
# Import Dependencies

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Load the Data

# %%
df = pd.read_csv('car_prices.csv')

# %% [markdown]
# Data Exploring

# %%
df.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller    mmr  sellingprice  \
# 0                 kia motors america  inc  20500         21500
# ...

# %% [markdown]
# ***Delete rows with Missing Values***

# %%
car_type = df.dropna(subset=['transmission'])

# %% [markdown]
# ***Count number of car company in type of transmission***

# %%
car_count = car_type['transmission'].value_counts()

# %%
df.groupby('make').agg({'transmission' : 'count'})
# Out:
#          transmission
# make
# Acura              80
# Audi              101
# BMW               532
# Bentley             5
# Buick              29
# ...               ...
# pontiac             1
# porsche             2
# smart               2
# subaru              1
# toyota              8
#
# [69 rows x 1 columns]

# %%
car_type.shape
# Out:
# (6212, 16)

# %% [markdown]
# ***Data Exploration***

# %%
car_type.head(5)
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller    mmr  sellingprice  \
# 0                 kia motors america  inc  20500         21500
# ...

# %%
car_type.tail(5)
# Out:
#       year           make    model        trim         body transmission  \
# 6571  2012  Mercedes-Benz  E-Class        E550  Convertible    automatic
# 6572  2012  Mercedes-Benz  E-Class        E550  Convertible    automatic
# 6573  2012  Mercedes-Benz  C-Class        C250        Coupe    automatic
# 6574  2012  Mercedes-Benz  C-Class  C250 Sport        Sedan    automatic
# 6575  2012  Mercedes-Benz  C-Class  C250 Sport        Sedan    automatic
#
#                     vin state  condition  odometer  color interior  \
# 6571  wddkk7df7cf179378    ca       36.0   19669.0      —    black
# 6572  wddkk7df1cf174063    ca       39.0    9707.0   gray    black
# 6573  wddgj4hb4cf801272    ca       32.0   26368.0  white      red
# 6574  wddgf4hb0cr216186    ca       42.0   44826.0      —    black
# 6575  wddgf4hb9ca620098    ca       39.0   30281.0  white     gray
#
#                                       seller    mmr  sellingprice  \
# ...

# %%
car_type.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6212 entries, 0 to 6575
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          6212 non-null   int64
#  1   make          6189 non-null   object
#  2   model         6188 non-null   object
#  3   trim          6168 non-null   object
#  4   body          6042 non-null   object
#  5   transmission  6212 non-null   object
#  6   vin           6212 non-null   object
#  7   state         6212 non-null   object
#  8   condition     5617 non-null   float64
#  9   odometer      6210 non-null   float64
#  10  color         6206 non-null   object
#  11  interior      6206 non-null   object
#  12  seller        6212 non-null   object
#  13  mmr           6212 non-null   int64
#  14  sellingprice  6212 non-null   int64
#  15  saledate      6212 non-null   object
# dtypes: float64(2), int64(3), object(11)
# memory usage: 825.0+ KB

# %%
car_type.describe()
# Out:
#               year    condition       odometer            mmr   sellingprice
# count  6212.000000  5617.000000    6210.000000    6212.000000    6212.000000
# mean   2009.773503    29.831583   65980.221256   15083.213941   14769.309723
# std       4.322127    14.545627   57703.808029   12015.703983   12086.190243
# min    1987.000000     1.000000       1.000000      25.000000     100.000000
# 25%    2007.000000    21.000000   24214.500000    6925.000000    6400.000000
# 50%    2012.000000    35.000000   43947.000000   12850.000000   12600.000000
# 75%    2013.000000    42.000000   98703.500000   20200.000000   20000.000000
# max    2015.000000    49.000000  999999.000000  149000.000000  154000.000000

# %% [markdown]
# ***Plotting a Bar Plot***

# %%
sns.barplot(data=car_type,y='sellingprice',x='transmission')
plt.figure(figsize=(50,10))
