# %% [markdown]
# ## ***PRODIGY_DS_05***

# %% [markdown]
# ***Import Dependencies***

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
from sklearn import preprocessing
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ***Load Data***

# %%
accident = pd.read_csv('accident_data.csv')

# %%
accident.shape
# Out:
# (147, 17)

# %%
accident.head()
# Out:
#          Date      Time  Latitude  Longitude Location Description  \
# 0  05-01-2022  15:30:00   40.7128   -74.0060              Highway
# 1  10-02-2022  18:45:00   41.8781   -87.6298               Street
# 2  15-03-2022  12:00:00   37.7749  -122.4194         Intersection
# 3  20-04-2022  09:20:00   34.0522  -118.2437              Highway
# 4  25-05-2022  17:10:00   40.7128   -74.0060               Street
#
#   Weather Conditions Road Conditions Visibility Accident Type Injury Severity  \
# 0              Foggy             Wet       Poor     Collision        Moderate
# 1              Rainy             Wet       Poor      Rollover          Severe
# 2              Clear             Dry      Clear     Collision        Moderate
# 3              Clear             Dry      Clear     Collision           Minor
# 4              Rainy             Wet       Poor     Collision          Severe
#
#   Contributing Factors Vehicle Type  No of Vehichles  Vehicle Speed  \
# ...

# %%
accident.info
# Out:
# <bound method DataFrame.info of            Date      Time  Latitude  Longitude Location Description  \
# 0    05-01-2022  15:30:00   40.7128   -74.0060              Highway
# 1    10-02-2022  18:45:00   41.8781   -87.6298               Street
# 2    15-03-2022  12:00:00   37.7749  -122.4194         Intersection
# 3    20-04-2022  09:20:00   34.0522  -118.2437              Highway
# 4    25-05-2022  17:10:00   40.7128   -74.0060               Street
# ..          ...       ...       ...        ...                  ...
# 142  10-08-2024  12:45:00   40.7128   -74.0060               Street
# 143  15-09-2024  08:30:00   37.7749  -122.4194              Highway
# 144  20-10-2024  16:20:00   34.0522  -118.2437               Street
# 145  25-11-2024  14:10:00   40.7128   -74.0060         Intersection
# 146  30-12-2024  10:00:00   41.8781   -87.6298              Highway
#
#     Weather Conditions Road Conditions Visibility Accident Type  \
# ...

# %%
accident.describe()
# Out:
#          Latitude   Longitude  No of Vehichles  Vehicle Speed         Year
# count  147.000000  147.000000       147.000000     147.000000   147.000000
# mean    38.325525  -98.649265         1.428571      38.843537  2022.979592
# std      3.197276   20.962406         0.496564       8.110285     0.823203
# min     34.052200 -122.419400         1.000000      25.000000  2022.000000
# 25%     34.052200 -118.243700         1.000000      30.000000  2022.000000
# 50%     40.712800  -87.629800         1.000000      35.000000  2023.000000
# 75%     40.712800  -74.006000         2.000000      45.000000  2024.000000
# max     41.878100  -74.006000         2.000000      55.000000  2024.000000

# %% [markdown]
# ***Drop Time and Date Column***

# %%
accident.drop(['Date','Time'], axis=1, inplace=True)

# %%
accident.head(2)
# Out:
#    Latitude  Longitude Location Description Weather Conditions  \
# 0   40.7128   -74.0060              Highway              Foggy
# 1   41.8781   -87.6298               Street              Rainy
#
#   Road Conditions Visibility Accident Type Injury Severity  \
# 0             Wet       Poor     Collision        Moderate
# 1             Wet       Poor      Rollover          Severe
#
#   Contributing Factors Vehicle Type  No of Vehichles  Vehicle Speed  \
# 0             Speeding        Truck                1             45
# 1        Drunk Driving   Motorcycle                1             40
#
#   Day of Week     Month  Year
# 0   Wednesday   January  2022
# 1    Thursday  February  2022

# %% [markdown]
# ***Label Encoding***

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
accident['Location Description']= label_encoder.fit_transform(accident['Location Description'])

# %%
accident['Weather Conditions']= label_encoder.fit_transform(accident['Weather Conditions'])

# %%
accident['Road Conditions']= label_encoder.fit_transform(accident['Road Conditions'])

# %%
accident['Visibility']= label_encoder.fit_transform(accident['Visibility'])

# %%
accident['Accident Type']= label_encoder.fit_transform(accident['Accident Type'])

# %%
accident['Injury Severity']= label_encoder.fit_transform(accident['Injury Severity'])

# %%
accident['Contributing Factors']= label_encoder.fit_transform(accident['Contributing Factors'])

# %%
accident['Vehicle Type']= label_encoder.fit_transform(accident['Vehicle Type'])

# %%
accident['Day of Week']= label_encoder.fit_transform(accident['Day of Week'])

# %%
accident['Month']= label_encoder.fit_transform(accident['Month'])

# %%
accident.head(10)
# Out:
#    Latitude  Longitude  Location Description  Weather Conditions  \
# 0   40.7128   -74.0060                     0                   1
# 1   41.8781   -87.6298                     2                   2
# 2   37.7749  -122.4194                     1                   0
# 3   34.0522  -118.2437                     0                   0
# 4   40.7128   -74.0060                     2                   2
# 5   41.8781   -87.6298                     1                   0
# 6   34.0522  -118.2437                     2                   0
# 7   40.7128   -74.0060                     0                   2
# 8   37.7749  -122.4194                     1                   0
# 9   34.0522  -118.2437                     0                   0
#
#    Road Conditions  Visibility  Accident Type  Injury Severity  \
# 0                1           1              0                1
# 1                1           1              1                2
# ...

# %% [markdown]
# ***Rounding Off***

# %%
accident.Latitude.apply(np.round)
# Out:
# 0      41.0
# 1      42.0
# 2      38.0
# 3      34.0
# 4      41.0
#        ...
# 142    41.0
# 143    38.0
# 144    34.0
# 145    41.0
# 146    42.0
# Name: Latitude, Length: 147, dtype: float64

# %%
accident.Longitude.apply(np.round)
# Out:
# 0      -74.0
# 1      -88.0
# 2     -122.0
# 3     -118.0
# 4      -74.0
#        ...
# 142    -74.0
# 143   -122.0
# 144   -118.0
# 145    -74.0
# 146    -88.0
# Name: Longitude, Length: 147, dtype: float64

# %%
sns.heatmap(accident.corr())
# Out:
# <Axes: >

# %% [markdown]
# ***Checking Null and Duplicated Value***

# %%
accident.isna().sum()
# Out:
# Latitude                0
# Longitude               0
# Location Description    0
# Weather Conditions      0
# Road Conditions         0
# Visibility              0
# Accident Type           0
# Injury Severity         0
# Contributing Factors    0
# Vehicle Type            0
# No of Vehichles         0
# Vehicle Speed           0
# Day of Week             0
# Month                   0
# Year                    0
# dtype: int64

# %%
accident.duplicated().sum()
# Out:
# 110

# %% [markdown]
# ***Outliers***

# %%
sns.boxplot(accident)
# Out:
# <Axes: >

# %% [markdown]
# ***Visualization***

# %%
sns.catplot(x='Weather Conditions', y='Vehicle Speed', hue='Injury Severity',data=accident)
plt.figure(figsize=(10,20))
plt.show()

# %%
accident['Injury Severity'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Injury Severity'>

# %%
sns.heatmap(pd.crosstab(accident['No of Vehichles'],accident['Month']))
# Out:
# <Axes: xlabel='Month', ylabel='No of Vehichles'>

# %%
sns.distplot(accident['Contributing Factors'])
# Out:
# <Axes: xlabel='Contributing Factors', ylabel='Density'>

# %%
sns.scatterplot(x='Location Description', y='Vehicle Speed', hue='Injury Severity',data=accident)
plt.show()

# %%
sns.boxplot(x='Road Conditions', y='Accident Type', hue='Vehicle Type', data=accident)
plt.show()

# %%
plt.hist(accident['Month'],histtype=u'bar',rwidth=0.8)
plt.show()

# %%
sns.distplot(accident[accident['Accident Type']==0]['Road Conditions'],hist=False)
sns.distplot(accident[accident['Accident Type']==1]['Road Conditions'],hist=False)
# Out:
# <Axes: xlabel='Road Conditions', ylabel='Density'>

# %% [markdown]
# ***Drop Columns***

# %%
accident.drop(['Day of Week','Month','Year','Latitude','Longitude','No of Vehichles'], axis=1, inplace=True)

# %%
accident.head()
# Out:
#    Location Description  Weather Conditions  Road Conditions  Visibility  \
# 0                     0                   1                1           1
# 1                     2                   2                1           1
# 2                     1                   0                0           0
# 3                     0                   0                0           0
# 4                     2                   2                1           1
#
#    Accident Type  Injury Severity  Contributing Factors  Vehicle Type  \
# 0              0                1                     3             2
# 1              1                2                     1             1
# 2              0                1                     4             0
# 3              0                0                     2             0
# 4              0                2                     3             0
#
#    Vehicle Speed
# 0             45
# 1             40
# 2             25
# 3             35
# ...

# %% [markdown]
# ***Finding S Algorithm***

# %%
d = np.array(accident)
print("n The attributes are: ",accident)
# Out:
# n The attributes are:       Location Description  Weather Conditions  Road Conditions  Visibility  \
# 0                       0                   1                1           1
# 1                       2                   2                1           1
# 2                       1                   0                0           0
# 3                       0                   0                0           0
# 4                       2                   2                1           1
# ..                    ...                 ...              ...         ...
# 142                     2                   2                1           1
# 143                     0                   0                0           0
# 144                     2                   0                0           0
# 145                     1                   2                1           1
# 146                     0                   0                0           0
#
# ...

# %%
target = np.array(accident['Injury Severity'])
print("n The target is: ",target)
# Out:
# n The target is:  [1 2 1 0 2 0 1 2 1 0 2 0 1 2 1 0 2 0 1 2 1 0 2 0 1 2 1 0 2 0 1 2 1 0 2 0 0
#  1 2 1 0 2 0 1 2 1 0 2 0 1 2 1 0 2 0 1 2 1 0 2 0 1 2 1 0 2 0 1 2 1 0 2 0 0
#  1 2 1 0 2 0 1 2 1 0 2 0 1 2 1 0 2 0 1 2 1 0 2 0 1 2 1 0 2 0 1 2 1 0 2 0 0
#  1 2 1 0 2 0 1 2 1 0 2 0 1 2 1 0 2 0 1 2 1 0 2 0 1 2 1 0 2 0 1 2 1 0 2 0]

# %%
def train(c,t):
    for i, val in enumerate(t):
        if val == "Yes":
            specific_hypothesis = c[i].copy()
            break
    for i, val in enumerate(c):
        if t[i] == "Yes":
            for x in range(len(specific_hypothesis)):
                if val[x] != specific_hypothesis[x]:
                    specific_hypothesis[x] = '?'
                else:
                    pass
        return specific_hypothesis

# %%
print("\nThe Find S hyposthesis is as follows")
print("The final hypothesis is:",train)
# Out:
# The Find S hyposthesis is as follows
# The final hypothesis is: <function train at 0x7e77a8c76e60>
